# %%
import pandas as pd

# %%
file = "DATI/2015/" + "1_2015" + '.xlsx'

# %%
xl = pd.ExcelFile(file)

# %%
df = pd.read_excel (xl, 'Dettaglio Brand & Channel', skiprows = 17 , usecols = "C:E,I:K")

# %%
df.head(20)
# Out:
#    TOTAL DIGITAL AUDIENCE      PC  MOBILE TOTAL DIGITAL AUDIENCE (mm:ss)  \
# 0                   11234    6680    4554                          02:58
# 1                     177       0     177                          00:02
# 2                  432928  204658  231007                          02:17
# 3                      20      20       0                          00:32
# 4                      10      10       0                          00:16
# 5                     567     567       0                          06:08
# 6                      32      32       0                          01:47
# 7                     110       3     107                          00:45
# 8                      87      87       0                          00:51
# 9                     350     268      82                          02:09
# 10                    142     125      17                          01:15
# 11                  44459   35404    9055                          03:01
# ...
